# %%
import pandas as pd
import numpy as np
import pickle

# %%
# !pwd
# Out:
# /home/mragletdinov/new_science

# %%
path = '/home/mragletdinov/new_science/data'

# %%
df_AEI_and_ADAR_expr_by_SRR = pd.read_csv(f'{path}/df_AEI_and_ADAR_expr_by_SRR.csv.gz', usecols = ['Sample', 'AEI'],sep='\t')
df_AEI_and_ADAR_expr_by_SRR#подгрузим просто чтобы было. Весь необходимый маппинг уже в файле SRR_GTEX.pickle
# Out:
#           Sample    AEI
# 0     SRR1072367  1.870
# 1     SRR1443612  1.558
# 2     SRR1458595  1.929
# 3     SRR1488172  2.091
# 4     SRR1491311  1.911
# ...          ...    ...
# 8533   SRR812461  0.972
# 8534  SRR1417936  2.109
# 8535  SRR1080720  1.221
# 8536   SRR614984  2.159
# 8537  SRR1409351  2.071
#
# [8538 rows x 2 columns]

# %%
with open(f'{path}/SRR_GTEX.pickle', 'rb') as f:
    SRR_GTEX = pickle.load(f)

# %%
SRR_GTEX
# Out:
# {'SRR1072367': 'GTEX-XMD1-0011-R10A-SM-4AT4A',
#  'SRR1443612': 'GTEX-139UW-0011-R9b-SM-5LZYT',
#  'SRR1458595': 'GTEX-14BIL-0011-R9a-SM-5SI7A',
#  'SRR1488172': 'GTEX-QDT8-0011-R9A-SM-5SI8J',
#  'SRR1491311': 'GTEX-13RTJ-0011-R9a-SM-5Q5AY',
#  'SRR1404601': 'GTEX-13RTJ-0011-R1a-SM-5O9D9',
#  'SRR1086635': 'GTEX-XMD1-0011-R8A-SM-4AT48',
#  'SRR817686': 'GTEX-X4XX-0011-R2A-SM-3P623',
#  'SRR1430884': 'GTEX-ZAB4-0011-R2a-SM-4RGNP',
#  'SRR665241': 'GTEX-QDT8-0011-R9A-SM-32PKH',
#  'SRR1474137': 'GTEX-13PLJ-0011-R9b-SM-5O9DV',
#  'SRR817880': 'GTEX-WL46-0011-R9A-SM-3MJFP',
#  'SRR602365': 'GTEX-N7MT-0011-R3a-SM-2I3GC',
#  'SRR612407': 'GTEX-RNOR-0011-R9A-SM-2TF52',
#  'SRR603397': 'GTEX-NPJ7-0011-R2a-SM-2I3GF',
#  'SRR1413768': 'GTEX-13N2G-0011-R9b-SM-5MR4E',
#  'SRR1415337': 'GTEX-13NYB-0011-R2a-SM-5MR3C',
#  'SRR1359673': 'GTEX-132Q8-0011-R2b-SM-5EQ5Z',
#  'SRR1093773': 'GTEX-XMD1-0011-R1A-SM-4AT4C',
#  'SRR1078347': 'GTEX-XMD1-0011-R3B-SM-4AT5R',
# ...

# %%
len(SRR_GTEX)
# Out:
# 8538

# %%
dict_of_columns_names_on_dtypes = dict()
for GTEX in SRR_GTEX.values():
    dict_of_columns_names_on_dtypes[GTEX] = np.float32

# %%
dict_of_columns_names_on_dtypes
# Out:
# {'GTEX-XMD1-0011-R10A-SM-4AT4A': numpy.float32,
#  'GTEX-139UW-0011-R9b-SM-5LZYT': numpy.float32,
#  'GTEX-14BIL-0011-R9a-SM-5SI7A': numpy.float32,
#  'GTEX-QDT8-0011-R9A-SM-5SI8J': numpy.float32,
#  'GTEX-13RTJ-0011-R9a-SM-5Q5AY': numpy.float32,
#  'GTEX-13RTJ-0011-R1a-SM-5O9D9': numpy.float32,
#  'GTEX-XMD1-0011-R8A-SM-4AT48': numpy.float32,
#  'GTEX-X4XX-0011-R2A-SM-3P623': numpy.float32,
#  'GTEX-ZAB4-0011-R2a-SM-4RGNP': numpy.float32,
#  'GTEX-QDT8-0011-R9A-SM-32PKH': numpy.float32,
#  'GTEX-13PLJ-0011-R9b-SM-5O9DV': numpy.float32,
#  'GTEX-WL46-0011-R9A-SM-3MJFP': numpy.float32,
#  'GTEX-N7MT-0011-R3a-SM-2I3GC': numpy.float32,
#  'GTEX-RNOR-0011-R9A-SM-2TF52': numpy.float32,
#  'GTEX-NPJ7-0011-R2a-SM-2I3GF': numpy.float32,
#  'GTEX-13N2G-0011-R9b-SM-5MR4E': numpy.float32,
#  'GTEX-13NYB-0011-R2a-SM-5MR3C': numpy.float32,
#  'GTEX-132Q8-0011-R2b-SM-5EQ5Z': numpy.float32,
#  'GTEX-XMD1-0011-R1A-SM-4AT4C': numpy.float32,
#  'GTEX-XMD1-0011-R3B-SM-4AT5R': numpy.float32,
# ...

# %%
#Попытались сразу же выводить необходимые нам столбцы из таблицы по экспрессии всех генов (в необходимом порядке).
rna_seq_data = pd.read_csv(f'{path}/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct', skiprows = 2, 
                           sep = '\t', chunksize = 100, 
                           dtype = dict_of_columns_names_on_dtypes,
                          usecols = list(dict_of_columns_names_on_dtypes.keys()))#вывести в том порядке, как нам надо, не получилось. Поэтому сделаем это постфактум
df_expressions = pd.concat(rna_seq_data)
#Как можно заметить, возникает ошибка. Она вызвана отсутсвием некоторых записей GTEX в таблице по экспрессиям. Хорошо что мы знаем их поименно.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [13], line 2
#       1 #Попытались сразу же выводить необходимые нам столбцы из таблицы по экспрессии всех генов (в необходимом порядке).
# ----> 2 rna_seq_data = pd.read_csv(f'{path}/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct', skiprows = 2,
#       3                            sep = '\t', chunksize = 100,
#       4                            dtype = dict_of_columns_names_on_dtypes,
#       5                           usecols = list(dict_of_columns_names_on_dtypes.keys()))#вывести в том порядке, как нам надо, не получилось. Поэтому сделаем это постфактум
#       6 df_expressions = pd.concat(rna_seq_data)
#
# File ~/anaconda3/envs/science/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
error_GTEX = ['GTEX-13NZ8-2126-SM-5L3EO', 'GTEX-ZVZQ-0426-SM-59HLT', 'GTEX-R55F-0011-R6A-SM-2TF4L', 'GTEX-RVPU-0011-R4A-SM-5SI8K', 'GTEX-YEC3-0726-SM-4YCD1', 'GTEX-PLZ5-0006-SM-5S2W5', 'GTEX-R55F-1326-SM-2TF5F', 'GTEX-PLZ6-0626-SM-5J1P1', 'GTEX-12WSB-0726-SM-5N9GD', 'GTEX-131XF-0926-SM-5BC69', 'GTEX-S32W-0726-SM-5S2T3', 'GTEX-S4Q7-0126-SM-4AD5P', 'GTEX-XXEK-2226-SM-5S2SA', 'GTEX-QESD-0726-SM-4R1KQ', 'GTEX-PWN1-0006-SM-5SI7T', 'GTEX-13OW8-2426-SM-5L3ID', 'GTEX-SIU7-1426-SM-4BRWT', 'GTEX-145MI-0011-R7b-SM-5
len(error_GTEX)#вот они, слева направо
# Out:
# 788

# %% [markdown]
# Два варианта сделать одно и тоже:

# %%
list_of_columns_names_on_dtypes = list(dict_of_columns_names_on_dtypes.keys())
list_of_columns_names_on_dtypes = [colname for colname in list_of_columns_names_on_dtypes if colname not in error_GTEX]
list_of_columns_names_on_dtypes.insert(0, 'Description')
list_of_columns_names_on_dtypes.insert(0, 'Name')
list_of_columns_names_on_dtypes
# Out:
# ['Name',
#  'Description',
#  'GTEX-XMD1-0011-R10A-SM-4AT4A',
#  'GTEX-139UW-0011-R9b-SM-5LZYT',
#  'GTEX-14BIL-0011-R9a-SM-5SI7A',
#  'GTEX-13RTJ-0011-R9a-SM-5Q5AY',
#  'GTEX-13RTJ-0011-R1a-SM-5O9D9',
#  'GTEX-XMD1-0011-R8A-SM-4AT48',
#  'GTEX-X4XX-0011-R2A-SM-3P623',
#  'GTEX-ZAB4-0011-R2a-SM-4RGNP',
#  'GTEX-13PLJ-0011-R9b-SM-5O9DV',
#  'GTEX-WL46-0011-R9A-SM-3MJFP',
#  'GTEX-N7MT-0011-R3a-SM-2I3GC',
#  'GTEX-RNOR-0011-R9A-SM-2TF52',
#  'GTEX-NPJ7-0011-R2a-SM-2I3GF',
#  'GTEX-13N2G-0011-R9b-SM-5MR4E',
#  'GTEX-13NYB-0011-R2a-SM-5MR3C',
#  'GTEX-132Q8-0011-R2b-SM-5EQ5Z',
#  'GTEX-XMD1-0011-R1A-SM-4AT4C',
#  'GTEX-XMD1-0011-R3B-SM-4AT5R',
#  'GTEX-11UD1-0011-R2b-SM-5BC6O',
#  'GTEX-14BIN-0011-R9a-SM-5SI76',
#  'GTEX-X585-0011-R4B-SM-46MVH',
#  'GTEX-NPJ8-0011-R3a-SM-2HMIW',
#  'GTEX-14ABY-0011-R9a-SM-5PNZK',
#  'GTEX-QVUS-0011-R1A-SM-3GAD2',
#  'GTEX-N7MT-0011-R2a-SM-2I3GI',
#  'GTEX-QDT8-0011-R2A-SM-32PKQ',
#  'GTEX-13G51-3026-SM-5IJB8',
#  'GTEX-YJ89-0011-R9a-SM-4SOK7',
# ...

# %%
len(list_of_columns_names_on_dtypes)
# Out:
# 7752

# %% [markdown]
# или

# %% [markdown]
# list_of_columns_names_on_dtypes_2 = list(dict_of_columns_names_on_dtypes.keys())
# for GTEX in error_GTEX:
#     list_of_columns_names_on_dtypes_2.remove(GTEX)
# list_of_columns_names_on_dtypes_2.insert(0, 'Description')
# list_of_columns_names_on_dtypes_2.insert(0, 'Name')

# %% [markdown]
# list_of_columns_names_on_dtypes_2

# %% [markdown]
# len(list_of_columns_names_on_dtypes_2)

# %% [markdown]
# list_of_columns_names_on_dtypes == list_of_columns_names_on_dtypes_2

# %%
rna_seq_data = pd.read_csv(f'{path}/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_tpm.gct', skiprows = 2, 
                           sep = '\t', chunksize = 100, 
                           dtype = dict_of_columns_names_on_dtypes,
                          usecols = list_of_columns_names_on_dtypes)#вывести в том порядке, как нам надо, не получилось. Поэтому сделаем это постфактум
df_expressions = pd.concat(rna_seq_data)

# %%
df_expressions
# Out:
#                     Name  Description  GTEX-1117F-0226-SM-5GZZ7  \
# 0      ENSG00000223972.5      DDX11L1                   0.00000
# 1      ENSG00000227232.5       WASH7P                   8.76400
# 2      ENSG00000278267.1    MIR6859-1                   0.00000
# 3      ENSG00000243485.5  MIR1302-2HG                   0.07187
# 4      ENSG00000237613.2      FAM138A                   0.00000
# ...                  ...          ...                       ...
# 56195  ENSG00000198695.2       MT-ND6                3799.00000
# 56196  ENSG00000210194.1        MT-TE                  16.24000
# 56197  ENSG00000198727.2       MT-CYB                6938.00000
# 56198  ENSG00000210195.2        MT-TT                   0.94300
# 56199  ENSG00000210196.2        MT-TP                   0.00000
#
#        GTEX-1117F-0426-SM-5EGHI  GTEX-1117F-0526-SM-5EGHJ  \
# 0                      0.000000                     0.000
# 1                      3.861000                     7.349
# ...

# %%
df_expressions = df_expressions[list_of_columns_names_on_dtypes]#почему-то команда usecols не отработала так как нужно. Сделает это более робастно.
df_expressions
# Out:
#                     Name  Description  GTEX-XMD1-0011-R10A-SM-4AT4A  \
# 0      ENSG00000223972.5      DDX11L1                       0.02728
# 1      ENSG00000227232.5       WASH7P                       3.09000
# 2      ENSG00000278267.1    MIR6859-1                       0.00000
# 3      ENSG00000243485.5  MIR1302-2HG                       0.00000
# 4      ENSG00000237613.2      FAM138A                       0.00000
# ...                  ...          ...                           ...
# 56195  ENSG00000198695.2       MT-ND6                    7260.00000
# 56196  ENSG00000210194.1        MT-TE                      19.83000
# 56197  ENSG00000198727.2       MT-CYB                   18220.00000
# 56198  ENSG00000210195.2        MT-TT                       1.42900
# 56199  ENSG00000210196.2        MT-TP                       6.24300
#
#        GTEX-139UW-0011-R9b-SM-5LZYT  GTEX-14BIL-0011-R9a-SM-5SI7A  \
# 0                             0.000                       0.00000
# ...

# %%
mt_genes_list = [i for i in df_expressions["Description"].to_list() if 'MT' not in i.split('-')]
mt_genes_list
# Out:
# ['DDX11L1',
#  'WASH7P',
#  'MIR6859-1',
#  'MIR1302-2HG',
#  'FAM138A',
#  'OR4G4P',
#  'OR4G11P',
#  'OR4F5',
#  'RP11-34P13.7',
#  'CICP27',
#  'RP11-34P13.15',
#  'RP11-34P13.16',
#  'RP11-34P13.14',
#  'RP11-34P13.13',
#  'RNU6-1100P',
#  'RP11-34P13.9',
#  'ABC7-43046700E7.1',
#  'RP11-34P13.18',
#  'MIR6859-2',
#  'AP006222.2',
#  'RPL23AP24',
#  'RP5-857K21.15',
#  'RP4-669L17.2',
#  'RP4-669L17.10',
#  'WBP1LP7',
#  'OR4F29',
#  'CICP7',
#  'RP4-669L17.8',
#  'U6',
#  'RP5-857K21.4',
#  'RP5-857K21.2',
#  'MTND1P23',
#  'MTND2P28',
#  'MTCO1P12',
#  'MTCO2P12',
#  'MTATP8P1',
#  'MTATP6P1',
#  'MTCO3P12',
#  'WBP1LP6',
#  'OR4F16',
#  'RP11-206L10.17',
#  'CICP3',
#  'RP11-206L10.2',
#  'RNU6-1199P',
#  'RP11-206L10.4',
#  'RP11-206L10.9',
#  'RP11-206L10.8',
#  'FAM87B',
#  'LINC01128',
#  'LINC00115',
#  'FAM41C',
#  'TUBB8P11',
#  'FAM166AP3',
#  'RP11-54O7.16',
#  'RP11-54O7.1',
#  'RP11-54O7.2',
#  'RP11-54O7.3',
#  'SAMD11',
#  'NOC2L',
#  'KLHL17',
#  'PLEKHN1',
# ...

# %%
mask = df_expressions.Description.isin(mt_genes_list)
mask
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 56195    False
# 56196    False
# 56197    False
# 56198    False
# 56199    False
# Name: Description, Length: 56200, dtype: bool

# %%
df_expressions = df_expressions[mask].reset_index(drop=True)
df_expressions
# Out:
#                            Name  Description  GTEX-XMD1-0011-R10A-SM-4AT4A  \
# 0             ENSG00000223972.5      DDX11L1                       0.02728
# 1             ENSG00000227232.5       WASH7P                       3.09000
# 2             ENSG00000278267.1    MIR6859-1                       0.00000
# 3             ENSG00000243485.5  MIR1302-2HG                       0.00000
# 4             ENSG00000237613.2      FAM138A                       0.00000
# ...                         ...          ...                           ...
# 56158   ENSG00000223484.7_PAR_Y       TRPC6P                       0.00000
# 56159  ENSG00000124334.17_PAR_Y         IL9R                       0.00000
# 56160  ENSG00000185203.12_PAR_Y       WASIR1                       0.00000
# 56161  ENSG00000182484.15_PAR_Y       WASH6P                       0.00000
# 56162   ENSG00000227159.8_PAR_Y     DDX11L16                       0.00000
#
#        GTEX-139UW-0011-R9b-SM-5LZYT  GTEX-14BIL-0011-R9a-SM-5SI7A  \
# ...

# %%
#Создадим словарь {Name:Description}
ensmbl_name_nickname_mapping = dict(zip(df_expressions['Name'],df_expressions['Description']))
ensmbl_name_nickname_mapping
# Out:
# {'ENSG00000223972.5': 'DDX11L1',
#  'ENSG00000227232.5': 'WASH7P',
#  'ENSG00000278267.1': 'MIR6859-1',
#  'ENSG00000243485.5': 'MIR1302-2HG',
#  'ENSG00000237613.2': 'FAM138A',
#  'ENSG00000268020.3': 'OR4G4P',
#  'ENSG00000240361.1': 'OR4G11P',
#  'ENSG00000186092.4': 'OR4F5',
#  'ENSG00000238009.6': 'RP11-34P13.7',
#  'ENSG00000233750.3': 'CICP27',
#  'ENSG00000268903.1': 'RP11-34P13.15',
#  'ENSG00000269981.1': 'RP11-34P13.16',
#  'ENSG00000239906.1': 'RP11-34P13.14',
#  'ENSG00000241860.6': 'RP11-34P13.13',
#  'ENSG00000222623.1': 'RNU6-1100P',
#  'ENSG00000241599.1': 'RP11-34P13.9',
#  'ENSG00000279928.2': 'ABC7-43046700E7.1',
#  'ENSG00000279457.4': 'RP11-34P13.18',
#  'ENSG00000273874.1': 'MIR6859-2',
#  'ENSG00000228463.9': 'AP006222.2',
#  'ENSG00000236679.2': 'RPL23AP24',
#  'ENSG00000236743.1': 'RP5-857K21.15',
#  'ENSG00000236601.2': 'RP4-669L17.2',
#  'ENSG00000237094.11': 'RP4-669L17.10',
#  'ENSG00000269732.1': 'WBP1LP7',
#  'ENSG00000278566.1': 'OR4F29',
# ...

# %%
with open(f'{path}/ensmbl_name_nickname_mapping.pickle', 'wb') as f:
    pickle.dump(ensmbl_name_nickname_mapping, f)

# %% [markdown]
# Вырежем из предыдущего маппинга записи error

# %%
SRR_GTEX
# Out:
#  'SRR1078347': 'GTEX-XMD1-0011-R3B-SM-4AT5R',
#  'SRR1440699': 'GTEX-11UD1-0011-R2b-SM-5BC6O',
#  'SRR1362777': 'GTEX-14BIN-0011-R9a-SM-5SI76',
# ...

# %%
len(new_final_mapping)
# Out:
# 7750

# %%
with open(f'{path}/SRR_GTEX_after_removing_errors_GTX.pickle', 'wb') as f:
    pickle.dump(new_final_mapping, f)

# %% [markdown]
# Второй вариант

# %% [markdown]
# new_final_mapping_2 = dict()
# for sample in SRR_GTEX:
#     if SRR_GTEX[sample] in error_GTEX:
#         continue
#     else:
#         new_final_mapping_2[sample] = SRR_GTEX[sample]
# new_final_mapping_2

# %% [markdown]
# len(new_final_mapping_2)

# %% [markdown]
# new_final_mapping == new_final_mappingj

# %% [markdown]
# Также вырежеим из исходной таблицы df_AEI_and_ADAR_expr_by_SRR записи error.
# Первый вариант

# %%
mask = df_AEI_and_ADAR_expr_by_SRR.Sample.isin(new_final_mapping.keys())
mask
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 8533     True
# 8534     True
# 8535     True
# 8536     True
# 8537     True
# Name: Sample, Length: 8538, dtype: bool

# %%
df_AEI_and_ADAR_expr_by_SRR = df_AEI_and_ADAR_expr_by_SRR[mask].reset_index(drop=True)
df_AEI_and_ADAR_expr_by_SRR
# Out:
#           Sample    AEI
# 0     SRR1072367  1.870
# 1     SRR1443612  1.558
# 2     SRR1458595  1.929
# 3     SRR1491311  1.911
# 4     SRR1404601  2.022
# ...          ...    ...
# 7745   SRR812461  0.972
# 7746  SRR1417936  2.109
# 7747  SRR1080720  1.221
# 7748   SRR614984  2.159
# 7749  SRR1409351  2.071
#
# [7750 rows x 2 columns]

# %% [markdown]
# Второй вариант

# %% [markdown]
# df_AEI_and_ADAR_expr_by_SRR_2 = df_AEI_and_ADAR_expr_by_SRR.query(
#     f"Sample in {list(new_final_mapping.keys())}").reset_index(drop=True)

# %% [markdown]
# df_AEI_and_ADAR_expr_by_SRR_2

# %% [markdown]
# df_AEI_and_ADAR_expr_by_SRR == df_AEI_and_ADAR_expr_by_SRR_2

# %%
AEI_row = df_AEI_and_ADAR_expr_by_SRR.AEI.to_list()
AEI_row
# Out:
# [1.87,
#  1.558,
#  1.929,
#  1.911,
#  2.022,
#  2.225,
#  1.727,
#  2.007,
#  1.668,
#  1.842,
#  1.834,
#  2.145,
#  1.77,
#  1.915,
#  1.896,
#  1.933,
#  1.847,
#  1.721,
#  1.641,
#  1.787,
#  1.912,
#  1.743,
#  1.918,
#  1.938,
#  1.728,
#  1.836,
#  1.859,
#  1.769,
#  1.802,
#  1.826,
#  1.756,
#  1.765,
#  1.68,
#  1.859,
#  1.908,
#  1.611,
#  1.828,
#  2.039,
#  1.771,
#  1.796,
#  1.907,
#  2.126,
#  1.964,
#  2.04,
#  1.768,
#  1.773,
#  1.749,
#  1.692,
#  2.312,
#  2.243,
#  1.904,
#  1.881,
#  1.687,
#  1.537,
#  1.636,
#  2.184,
#  1.833,
#  1.724,
#  1.703,
#  1.986,
#  2.411,
#  2.111,
#  2.072,
#  1.766,
#  2.013,
#  2.046,
#  1.921,
#  1.763,
#  1.877,
#  1.755,
#  1.698,
#  2.047,
#  1.906,
#  1.935,
#  1.927,
#  1.799,
#  1.602,
#  1.858,
#  1.886,
#  1.754,
#  1.591,
#  1.907,
#  1.865,
#  2.108,
#  1.912,
#  1.723,
#  1.661,
#  2.049,
#  2.308,
#  2.024,
#  2.323,
#  1.474,
#  1.873,
#  2.176,
#  1.725,
#  2.238,
#  1.839,
#  2.019,
#  1.955,
#  2.052,
# ...

# %%
len(AEI_row)
# Out:
# 7750

# %% [markdown]
# AEI_row_2 = list(df_AEI_and_ADAR_expr_by_SRR.AEI)# Тоже самое, но длиннее
# AEI_row_2

# %% [markdown]
# len(AEI_row_2)

# %% [markdown]
# AEI_row == AEI_row_2

# %% [markdown]
# Добавим столбец AEI в таблицу df_expressions

# %%
AEI_row.insert(0, 'AEI')
AEI_row.insert(1, 'Alu-index')

# %%
AEI_row
# Out:
# ['AEI',
#  'Alu-index',
#  1.87,
#  1.558,
#  1.929,
#  1.911,
#  2.022,
#  2.225,
#  1.727,
#  2.007,
#  1.668,
#  1.842,
#  1.834,
#  2.145,
#  1.77,
#  1.915,
#  1.896,
#  1.933,
#  1.847,
#  1.721,
#  1.641,
#  1.787,
#  1.912,
#  1.743,
#  1.918,
#  1.938,
#  1.728,
#  1.836,
#  1.859,
#  1.769,
#  1.802,
#  1.826,
#  1.756,
#  1.765,
#  1.68,
#  1.859,
#  1.908,
#  1.611,
#  1.828,
#  2.039,
#  1.771,
#  1.796,
#  1.907,
#  2.126,
#  1.964,
#  2.04,
#  1.768,
#  1.773,
#  1.749,
#  1.692,
#  2.312,
#  2.243,
#  1.904,
#  1.881,
#  1.687,
#  1.537,
#  1.636,
#  2.184,
#  1.833,
#  1.724,
#  1.703,
#  1.986,
#  2.411,
#  2.111,
#  2.072,
#  1.766,
#  2.013,
#  2.046,
#  1.921,
#  1.763,
#  1.877,
#  1.755,
#  1.698,
#  2.047,
#  1.906,
#  1.935,
#  1.927,
#  1.799,
#  1.602,
#  1.858,
#  1.886,
#  1.754,
#  1.591,
#  1.907,
#  1.865,
#  2.108,
#  1.912,
#  1.723,
#  1.661,
#  2.049,
#  2.308,
#  2.024,
#  2.323,
#  1.474,
#  1.873,
#  2.176,
#  1.725,
#  2.238,
#  1.839,
# ...

# %%
df_expressions.loc[len(df_expressions.index)] = AEI_row
df_expressions
# Out:
#                            Name  Description  GTEX-XMD1-0011-R10A-SM-4AT4A  \
# 0             ENSG00000223972.5      DDX11L1                       0.02728
# 1             ENSG00000227232.5       WASH7P                       3.09000
# 2             ENSG00000278267.1    MIR6859-1                       0.00000
# 3             ENSG00000243485.5  MIR1302-2HG                       0.00000
# 4             ENSG00000237613.2      FAM138A                       0.00000
# ...                         ...          ...                           ...
# 56159  ENSG00000124334.17_PAR_Y         IL9R                       0.00000
# 56160  ENSG00000185203.12_PAR_Y       WASIR1                       0.00000
# 56161  ENSG00000182484.15_PAR_Y       WASH6P                       0.00000
# 56162   ENSG00000227159.8_PAR_Y     DDX11L16                       0.00000
# 56163                       AEI    Alu-index                       1.87000
#
#        GTEX-139UW-0011-R9b-SM-5LZYT  GTEX-14BIL-0011-R9a-SM-5SI7A  \
# ...

# %%
df_expressions.drop_duplicates(['Name','Description'])#полеых дубликатов не обнаружили. НО есть дубли по Description
# Out:
#                            Name  Description  GTEX-XMD1-0011-R10A-SM-4AT4A  \
# 0             ENSG00000223972.5      DDX11L1                       0.02728
# 1             ENSG00000227232.5       WASH7P                       3.09000
# 2             ENSG00000278267.1    MIR6859-1                       0.00000
# 3             ENSG00000243485.5  MIR1302-2HG                       0.00000
# 4             ENSG00000237613.2      FAM138A                       0.00000
# ...                         ...          ...                           ...
# 56159  ENSG00000124334.17_PAR_Y         IL9R                       0.00000
# 56160  ENSG00000185203.12_PAR_Y       WASIR1                       0.00000
# 56161  ENSG00000182484.15_PAR_Y       WASH6P                       0.00000
# 56162   ENSG00000227159.8_PAR_Y     DDX11L16                       0.00000
# 56163                       AEI    Alu-index                       1.87000
#
#        GTEX-139UW-0011-R9b-SM-5LZYT  GTEX-14BIL-0011-R9a-SM-5SI7A  \
# ...

# %%
df_expressions_with_AEI = df_expressions.set_index(['Name'])
df_expressions_with_AEI
# Out:
#                           Description  GTEX-XMD1-0011-R10A-SM-4AT4A  \
# Name
# ENSG00000223972.5             DDX11L1                       0.02728
# ENSG00000227232.5              WASH7P                       3.09000
# ENSG00000278267.1           MIR6859-1                       0.00000
# ENSG00000243485.5         MIR1302-2HG                       0.00000
# ENSG00000237613.2             FAM138A                       0.00000
# ...                               ...                           ...
# ENSG00000124334.17_PAR_Y         IL9R                       0.00000
# ENSG00000185203.12_PAR_Y       WASIR1                       0.00000
# ENSG00000182484.15_PAR_Y       WASH6P                       0.00000
# ENSG00000227159.8_PAR_Y      DDX11L16                       0.00000
# AEI                         Alu-index                       1.87000
#
#                           GTEX-139UW-0011-R9b-SM-5LZYT  \
# Name
# ENSG00000223972.5                                0.000
# ...

# %% [markdown]
# df_expressions_with_AEI = df_expressions.set_index(['Description'])
# df_expressions_with_AEI

# %%
df_expressions_with_AEI = df_expressions_with_AEI.drop('Description', 1)
# Out:
# <ipython-input-57-c50458516ba9>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_expressions_with_AEI = df_expressions_with_AEI.drop('Description', 1)

# %% [markdown]
# df_expressions_with_AEI = df_expressions_with_AEI.drop('Name', 1)

# %%
df_expressions_with_AEI
# Out:
#                           GTEX-XMD1-0011-R10A-SM-4AT4A  \
# Name
# ENSG00000223972.5                              0.02728
# ENSG00000227232.5                              3.09000
# ENSG00000278267.1                              0.00000
# ENSG00000243485.5                              0.00000
# ENSG00000237613.2                              0.00000
# ...                                                ...
# ENSG00000124334.17_PAR_Y                       0.00000
# ENSG00000185203.12_PAR_Y                       0.00000
# ENSG00000182484.15_PAR_Y                       0.00000
# ENSG00000227159.8_PAR_Y                        0.00000
# AEI                                            1.87000
#
#                           GTEX-139UW-0011-R9b-SM-5LZYT  \
# Name
# ENSG00000223972.5                                0.000
# ENSG00000227232.5                                4.808
# ENSG00000278267.1                                0.000
# ENSG00000243485.5                                0.000
# ...

# %%
df_expressions_with_AEI.to_csv(f'{path}/df_expressions_with_AEI.csv.gz', sep='\t',
                 compression='gzip'
                 )
